# %%
# !git status
# !ls -la .git
# Out:
# On branch main
# Your branch and 'origin/main' have diverged,
# and have 1 and 1 different commits each, respectively.
#   (use "git pull" if you want to integrate the remote branch with yours)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	git_ops.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
# total 212
# drwxrwxrwx+   8 codespace root        4096 Feb  4 02:59 .
# drwxrwxrwx+  29 codespace root        4096 Feb  4 02:48 ..
# -rw-rw-rw-    1 codespace codespace    102 Feb  4 02:40 COMMIT_EDITMSG
# -rw-rw-rw-    1 codespace root        1007 Feb  4 02:56 FETCH_HEAD
# -rw-rw-rw-    1 codespace codespace     21 Feb  4 02:05 HEAD
# -rw-rw-rw-    1 codespace codespace     41 Feb  4 02:18 ORIG_HEAD
# -rw-rw-rw-    1 codespace codespace     41 Feb  3 20:32 REBASE_HEAD
# -rw-rw-rw-    1 codespace codespace    699 Feb  4 02:05 config
# -rw-rw-rw-    1 codespace root          73 Feb  3 19:00 description
# drwxrwxrwx+   2 codespace root        4096 Feb  3 19:05 hooks
# -rw-rw-rw-    1 codespace codespace 149373 Feb  4 02:40 index
# drwxrwxrwx+   2 codespace root        4096 Feb  3 19:00 info
# drwxr-xr-x+   4 codespace codespace   4096 Feb  3 20:32 lfs
# drwxrwxrwx+   3 codespace root        4096 Feb  3 19:00 logs
# drwxrwxrwx+ 114 codespace root        4096 Feb  4 02:56 objects
# -rw-rw-rw-    1 codespace root         112 Feb  3 19:00 packed-refs
# drwxrwxrwx+   5 codespace root        4096 Feb  3 19:05 refs

# %%
# !git status
# !echo "--- Local commits not in remote ---"
# !git log origin/main..main --oneline --stat
# !echo "--- Remote commits not in local ---"
# !git log main..origin/main --oneline --stat
# Out:
# On branch main
# Your branch and 'origin/main' have diverged,
# and have 1 and 1 different commits each, respectively.
#   (use "git pull" if you want to integrate the remote branch with yours)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	git_ops.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)
# --- Local commits not in remote ---
# b0e0f6b (HEAD -> main) Improve OIDC discovery handling and enhance upsertUser logic with detailed error handling and logging
#  server/replitAuth.ts |  6 ++++
#  server/storage.ts    | 85 ++++++++++++++++++++++++++++++++++++++++++----------
#  2 files changed, 76 insertions(+), 15 deletions(-)
# --- Remote commits not in local ---
# 44a8de6 (origin/main, origin/HEAD) okj
#  .replit | 3 +--
#  1 file changed, 1 insertion(+), 2 deletions(-)

# %%
# !git config pull.rebase false
# !git pull origin main
# !git push origin main
# Out:
# From https://github.com/jasonbender-c3x/Meowstik
#  * branch            main       -> FETCH_HEAD
# hint: Waiting for your editor to close the file... 7[>4;2m="/workspaces/Meowstik/.git/MERGE_MSG" 6L, 293C▽  [>cMerge branch 'main' of https://github.com/jasonbender-c3x/Meowstik
# # Please enter a commit message to explain why this merge is necessary,
# # especially if it merges an updated upstream into a topic branch.
# #
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               ~                                                                               1,1All
